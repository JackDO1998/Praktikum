# %%
import numpy as np 
import matplotlib.pyplot as plt 
from uncertainties import ufloat
import uncertainties.unumpy as unp
from scipy.optimize import curve_fit
import scipy.constants as const

# %%
#Daten einlesen
X=[0]
T11r=np.genfromtxt('GLXportRun1_1.dat', usecols=(1))
T12r=np.genfromtxt('GLXportRun1_1.dat', usecols=(2))
T13r=np.genfromtxt('GLXportRun1_1.dat', usecols=(3))
T14r=np.genfromtxt('GLXportRun1_1.dat', usecols=(4))
T15r=np.genfromtxt('GLXportRun1_1.dat', usecols=(5))
T16r=np.genfromtxt('GLXportRun1_1.dat', usecols=(6))
T17r=np.genfromtxt('GLXportRun1_1.dat', usecols=(7))
T18r=np.genfromtxt('GLXportRun1_1.dat', usecols=(8))


T21r=np.genfromtxt('GLXportRun1_2.dat', usecols=(1))
T22r=np.genfromtxt('GLXportRun1_2.dat', usecols=(2))
T23r=np.genfromtxt('GLXportRun1_2.dat', usecols=(3))
T24r=np.genfromtxt('GLXportRun1_2.dat', usecols=(4))
T25r=np.genfromtxt('GLXportRun1_2.dat', usecols=(5))
T26r=np.genfromtxt('GLXportRun1_2.dat', usecols=(6))
T27r=np.genfromtxt('GLXportRun1_2.dat', usecols=(7))
T28r=np.genfromtxt('GLXportRun1_2.dat', usecols=(8))


T31r=np.genfromtxt('GLXportRun1_3.dat', usecols=(1))
T32r=np.genfromtxt('GLXportRun1_3.dat', usecols=(2))
T33r=np.genfromtxt('GLXportRun1_3.dat', usecols=(3))
T34r=np.genfromtxt('GLXportRun1_3.dat', usecols=(4))
T35r=np.genfromtxt('GLXportRun1_3.dat', usecols=(5))
T36r=np.genfromtxt('GLXportRun1_3.dat', usecols=(6))
T37r=np.genfromtxt('GLXportRun1_3.dat', usecols=(7))
T38r=np.genfromtxt('GLXportRun1_3.dat', usecols=(8))

t1=np.arange(0,(len(T11r)/5),0.2)
t2=np.arange(0,len(T31r),1)
t3=np.arange(0,(len(T51r)/2),0.5)

# %%
# Umrechnung in Kelvin
a=0
b=0
c=0
T11=X*len(T11r)
T12=X*len(T12r)
T13=X*len(T13r)
T14=X*len(T14r)
T15=X*len(T15r)
T16=X*len(T16r)
T17=X*len(T17r)
T18=X*len(T18r)

T21=X*len(T21r)
T22=X*len(T22r)
T23=X*len(T23r)
T24=X*len(T24r)
T25=X*len(T25r)
T26=X*len(T26r)
T27=X*len(T27r)
T28=X*len(T28r)


T31=X*len(T31r)
T32=X*len(T32r)
T33=X*len(T33r)
T34=X*len(T34r)
T35=X*len(T35r)
T36=X*len(T36r)
T37=X*len(T37r)
T38=X*len(T38r)

while a < len(T11r):
    T11[a]=T11r[a]+273.15
    T12[a]=T12r[a]+273.15
    T13[a]=T13r[a]+273.15
    T14[a]=T14r[a]+273.15
    T15[a]=T15r[a]+273.15
    T16[a]=T16r[a]+273.15
    T17[a]=T17r[a]+273.15
    T18[a]=T18r[a]+273.15
    a=a+1

while b < len(T21r):
    T21[b]=T21r[b]+273.15
    T22[b]=T22r[b]+273.15
    T23[b]=T23r[b]+273.15
    T24[b]=T24r[b]+273.15
    T25[b]=T25r[b]+273.15
    T26[b]=T26r[b]+273.15
    T27[b]=T27r[b]+273.15
    T28[b]=T28r[b]+273.15
    b=b+1

while c < len(T31r):
    T31[c]=T31r[c]+273.15
    T32[c]=T32r[c]+273.15
    T33[c]=T33r[c]+273.15
    T34[c]=T34r[c]+273.15
    T35[c]=T35r[c]+273.15
    T36[c]=T36r[c]+273.15
    T37[c]=T37r[c]+273.15
    T38[c]=T38r[c]+273.15
    c=c+1

# %%
# Temperatur nach 700s
T11700=T11[3500]
T14700=T14[3500]
T15700=T15[3500]
T18700=T18[3500]

print('Temp. nach 700s: T1=',T11700,' T4=',T14700,' T5=',T15700,' T8=',18700)
# Out:
# Temp. nach 700s: T1= 322.67999999999995  T4= 320.09999999999997  T5= 325.28  T8= 18700

# %%
#Statische Methode Plot 1
plt.plot(t1,T11,'g-',label='T1 Messing (Breit)')
plt.plot(t1,T14,'r-',label='T4 Messing (Schmal)')
plt.plot(t1,T11700*t1/t1,'k-',label='Temp. nach 700s')
plt.plot(t1,T14700*t1/t1,'k-')
plt.title('Temperaturverlauf Messing')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in K')
plt.legend(loc='best')
plt.savefig('statmessing.pdf')
# Out:
# <ipython-input-139-0e49c59c7484>:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(t1,T11700*t1/t1,'k-',label='Temp. nach 700s')
# <ipython-input-139-0e49c59c7484>:5: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(t1,T14700*t1/t1,'k-')

# %%
#Statische Methode Plot 2
plt.plot(t1,T15,'g-',label='T5 Aluminium')
plt.plot(t1,T18,'r-',label='T8 Edelstahl')
plt.plot(t1,T15700*t1/t1,'k-',label='Temp. nach 700s')
plt.plot(t1,T18700*t1/t1,'k-')
plt.title('Temperaturverlauf Aluminium / Edelstahl')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in K')
plt.legend(loc='best')
plt.savefig('stataluedel.pdf')
# Out:
# <ipython-input-140-b5a256176b5c>:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(t1,T15700*t1/t1,'k-',label='Temp. nach 700s')
# <ipython-input-140-b5a256176b5c>:5: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(t1,T18700*t1/t1,'k-')

# %%
# Out:
# Temp. nach 700s: T1= 49.53  T4= 46.95  T5= 52.13  T8= 18700

# %%
#Edelstahl
plt.plot(t1,T23r,'g-',label='T3')
plt.plot(t1,T24r,'r-',label='T4')
plt.title('Temperaturverlauf Edelstahl')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in K')
plt.legend(loc='best')

# %%
# Messing breit 2
plt.plot(t2,T31r,'g-',label='T3')
plt.plot(t2,T32r,'r-',label='T4')
plt.title('Temperaturverlauf Messing (breit)')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Messing Schmal 2
plt.plot(t2,T33r,'g-',label='T3')
plt.plot(t2,T34r,'r-',label='T4')
plt.title('Temperaturverlauf Messing (schmal)')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Aluminium 2
plt.plot(t2,T41r,'k-',label='T1')
plt.plot(t2,T42r,'b-',label='T2')
plt.title('Temperaturverlauf Aluminium')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Edelstahl 2
plt.plot(t2,T43r,'g-',label='T3')
plt.plot(t2,T44r,'r-',label='T4')
plt.title('Temperaturverlauf Edelstahl')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Messing breit 3
plt.plot(t3,T51r,'k-',label='T1')
plt.plot(t3,T52r,'b-',label='T2')
plt.title('Temperaturverlauf Messing (breit)')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Messing schmal 3
plt.plot(t3,T53r,'g-',label='T3')
plt.plot(t3,T54r,'r-',label='T4')
plt.title('Temperaturverlauf Messing (schmal)')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Aluminium 3
plt.plot(t3,T61r,'k-',label='T1')
plt.plot(t3,T62r,'b-',label='T2')
plt.title('Temperaturverlauf Aluminium')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')

# %%
#Edelstahl 4
plt.plot(t3,T63r,'g-',label='T3')
plt.plot(t3,T64r,'r-',label='T4')
plt.title('Temperaturverlauf Edelstahl')
plt.xlabel('Zeit $t$ in s')
plt.ylabel('Temperatur $T$ in °C')
plt.legend(loc='best')
